# %%
# %matplotlib inline
import sys
sys.path.append("/Users/mmeier/Desktop/new_arena/")
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy import stats
import pylab

# %% [markdown]
# # Use average of all ROIs

# %%
fly0_LO = np.load('T4T5_ctrl_edges_2016-11-07_17.59LO.npy').mean(2)
fly0_ME = np.load('T4T5_ctrl_edges_2016-11-07_17.59ME.npy').mean(2)
fly0_LP = np.load('T4T5_ctrl_edges_2016-11-07_17.59LP.npy').mean(2)

fly1_LO = np.load('T4T5_ctrl_edges_2016-11-10_15.42LO.npy').mean(2)
fly1_ME = np.load('T4T5_ctrl_edges_2016-11-10_15.42ME.npy').mean(2)
fly1_LP = np.load('T4T5_ctrl_edges_2016-11-10_15.42LP.npy').mean(2)

fly2_LO = np.load('T4T5_ctrl_edges_2016-11-14_15.13LO.npy').mean(2)
fly2_ME = np.load('T4T5_ctrl_edges_2016-11-14_15.13ME.npy').mean(2)
fly2_LP = np.load('T4T5_ctrl_edges_2016-11-14_15.13LP.npy').mean(2)

fly3_LO = np.load('T4T5_ctrl_edges_2016-11-15_17.38LO.npy').mean(2)
fly3_ME = np.load('T4T5_ctrl_edges_2016-11-15_17.38ME.npy').mean(2)
fly3_LP = np.load('T4T5_ctrl_edges_2016-11-15_17.38LP.npy').mean(2)

fly4_LO = np.load('T4T5_ctrl_edges_2016-11-16_14.59LO.npy').mean(2)
fly4_ME = np.load('T4T5_ctrl_edges_2016-11-16_14.59ME.npy').mean(2)
fly4_LP = np.load('T4T5_ctrl_edges_2016-11-16_14.59LP.npy').mean(2)

fly5_LO = np.load('T4T5_ctrl_edges_2016-11-18_18.32LO.npy').mean(2)
fly5_ME = np.load('T4T5_ctrl_edges_2016-11-18_18.32ME.npy').mean(2)
fly5_LP = np.load('T4T5_ctrl_edges_2016-11-18_18.32LP.npy').mean(2)

fly6_LO = np.load('T4T5_SHI_ctrl_edges_2016-11-21_15.47LO.npy').mean(2)
fly6_ME = np.load('T4T5_SHI_ctrl_edges_2016-11-21_15.47ME.npy').mean(2)
fly6_LP = np.load('T4T5_SHI_ctrl_edges_2016-11-21_15.47LP.npy').mean(2)

fly7_LO = np.load('T4T5_SHI_ctrl_edges_2016-11-30_15.35LO.npy').mean(2)
fly7_ME = np.load('T4T5_SHI_ctrl_edges_2016-11-30_15.35ME.npy').mean(2)
fly7_LP = np.load('T4T5_SHI_ctrl_edges_2016-11-30_15.35LP.npy').mean(2)

single_tuningsLO = np.array([fly0_LO, fly1_LO, fly2_LO, fly3_LO, fly4_LO, fly5_LO, fly6_LO, fly7_LO])
single_tuningsME = np.array([fly0_ME, fly1_ME, fly2_ME, fly3_ME, fly4_ME, fly5_ME, fly6_ME, fly7_ME])
single_tuningsLP = np.array([fly0_LP, fly1_LP, fly2_LP, fly3_LP, fly4_LP, fly5_LP, fly6_LP, fly7_LP])

SEM_LO = stats.sem(single_tuningsLO)
SEM_ME = stats.sem(single_tuningsME)
SEM_LP = stats.sem(single_tuningsLP)

mean_tuningLO = np.mean(single_tuningsLO, axis = 0)
mean_tuningME = np.mean(single_tuningsME, axis = 0)
mean_tuningLP = np.mean(single_tuningsLP, axis = 0)

mean_tuning = np.array([mean_tuningLO, mean_tuningME, mean_tuningLP])
SEMs = np.array([SEM_LO, SEM_ME, SEM_LP])

# %% [markdown]
# # Use only one large ROI

# %%
fly0_LO = np.load('T4T5_ctrl_edges_2016-11-07_17.59LO.npy')
fly0_LO = fly0_LO[:, :, 4]
fly0_ME = np.load('T4T5_ctrl_edges_2016-11-07_17.59ME.npy')
fly0_ME = fly0_ME[:, :, 4]
fly0_LP = np.load('T4T5_ctrl_edges_2016-11-07_17.59LP.npy')
fly0_LP = fly0_LP[:, :, 4]              

fly1_LO = np.load('T4T5_ctrl_edges_2016-11-10_15.42LO.npy')
fly1_LO = fly1_LO[:, :, 4]
fly1_ME = np.load('T4T5_ctrl_edges_2016-11-10_15.42ME.npy')
fly1_ME = fly1_ME[:, :, 4]
fly1_LP = np.load('T4T5_ctrl_edges_2016-11-10_15.42LP.npy')
fly1_LP = fly1_LP[:, :, 4]

fly2_LO = np.load('T4T5_ctrl_edges_2016-11-14_15.13LO.npy')
fly2_LO = fly2_LO[:, :, 4]
fly2_ME = np.load('T4T5_ctrl_edges_2016-11-14_15.13ME.npy')
fly2_ME = fly2_ME[:, :, 4]                  
fly2_LP = np.load('T4T5_ctrl_edges_2016-11-14_15.13LP.npy')
fly2_LP = fly2_LP[:, :, 4]                  

fly3_LO = np.load('T4T5_ctrl_edges_2016-11-15_17.38LO.npy')
fly3_LO = fly3_LO[:, :, 4]                  
fly3_ME = np.load('T4T5_ctrl_edges_2016-11-15_17.38ME.npy')
fly3_ME = fly3_ME[:, :, 4]                  
fly3_LP = np.load('T4T5_ctrl_edges_2016-11-15_17.38LP.npy')
fly3_LP = fly3_LP[:, :, 4]                  

fly4_LO = np.load('T4T5_ctrl_edges_2016-11-16_14.59LO.npy')
fly4_LO = fly4_LO[:, :, 4]                  
fly4_ME = np.load('T4T5_ctrl_edges_2016-11-16_14.59ME.npy')
fly4_ME = fly4_ME[:, :, 4]                  
fly4_LP = np.load('T4T5_ctrl_edges_2016-11-16_14.59LP.npy')
fly4_LP = fly4_LP[:, :, 4]                  

fly5_LO = np.load('T4T5_ctrl_edges_2016-11-18_18.32LO.npy')
fly5_LO = fly5_LO[:, :, 4]                  
fly5_ME = np.load('T4T5_ctrl_edges_2016-11-18_18.32ME.npy')
fly5_ME = fly5_ME[:, :, 4]                  
fly5_LP = np.load('T4T5_ctrl_edges_2016-11-18_18.32LP.npy')
fly5_LP = fly5_LP[:, :, 4]                  

fly6_LO = np.load('T4T5_SHI_ctrl_edges_2016-11-21_15.47LO.npy')
fly6_LO = fly6_LO[:, :, 4]                  
fly6_ME = np.load('T4T5_SHI_ctrl_edges_2016-11-21_15.47ME.npy')
fly6_ME = fly6_ME[:, :, 4]                  
fly6_LP = np.load('T4T5_SHI_ctrl_edges_2016-11-21_15.47LP.npy')
fly6_LP = fly6_LP[:, :, 4]          

fly7_LO = np.load('T4T5_SHI_ctrl_edges_2016-11-30_15.35LO.npy')
fly7_LO = fly7_LO[:, :, 4]                  
fly7_ME = np.load('T4T5_SHI_ctrl_edges_2016-11-30_15.35ME.npy')
fly7_ME = fly7_ME[:, :, 4]                  
fly7_LP = np.load('T4T5_SHI_ctrl_edges_2016-11-30_15.35LP.npy')
fly7_LP = fly7_LP[:, :, 4] 

single_tuningsLO = np.array([fly0_LO, fly1_LO, fly2_LO, fly3_LO, fly4_LO, fly5_LO, fly6_LO, fly7_LO])
single_tuningsME = np.array([fly0_ME, fly1_ME, fly2_ME, fly3_ME, fly4_ME, fly5_ME, fly6_ME, fly7_ME])
single_tuningsLP = np.array([fly0_LP, fly1_LP, fly2_LP, fly3_LP, fly4_LP, fly5_LP, fly6_LP, fly7_LP])

SEM_LO = stats.sem(single_tuningsLO)
SEM_ME = stats.sem(single_tuningsME)
SEM_LP = stats.sem(single_tuningsLP)

mean_tuningLO = np.mean(single_tuningsLO, axis = 0)
mean_tuningME = np.mean(single_tuningsME, axis = 0)
mean_tuningLP = np.mean(single_tuningsLP, axis = 0)

mean_tuning = np.array([mean_tuningLO, mean_tuningME, mean_tuningLP])
SEMs = np.array([SEM_LO, SEM_ME, SEM_LP])

# %%
print(np.shape(single_tuningsLO))
print(np.shape(SEM_LO))
print(np.shape(mean_tuningLO))
print(np.shape(mean_tuning))
print(np.shape(SEMs))
# Out:
# (8, 2, 12)
# (2, 12)
# (2, 12)
# (3, 2, 12)
# (3, 2, 12)

# %%
# plot everything

regions = [0,1,2]

for region in regions:
    plt.figure(figsize = (5,5))
    ax = plt.subplot(111)
    
    # here, we manually define the x-axis
    orientation_tuning = [0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330]

    # plot mean tuning as solid line
    plt.errorbar(orientation_tuning, mean_tuning[region,0,:], yerr=SEMs[region,0,:], color = 'b', linewidth = 3.0, marker = 'o')
    plt.errorbar(orientation_tuning, mean_tuning[region,1,:], yerr=SEMs[region,1,:], color = 'k', linewidth = 3.0, marker = 'o')

    # define the x-axis and ticks etc...
    ax.set_xlim([-30,360])
    ax.set_xticks([0,90,180,270])
    ax.set_xticklabels(['left','up','right','down'], fontsize = 15.)
    ax.set_xlabel('Orientation', fontsize = 20.)

    # define the y-axis and ticks etc...
    plt.ylim([0,1.1])
    ax.set_yticks([0.0, 0.5, 1.0])
    ax.set_yticklabels([0, 0.5, 1.0], fontsize = 20.)
    ax.set_ylabel('$\Delta F/F$', fontsize = 20.)
    plt.legend(['ON', 'OFF'])
    
    
    if region == 0:
        plt.title ("Lobula", fontsize = 20.)
        open('dir_tun' + 'LO.npy','w')
        np.save('dir_tun' + 'LO.npy', mean_tuning)
        ax.text(0.8, 0.8, "N={0}".format(np.shape(single_tuningsLO)[0]), transform=ax.transAxes, fontsize=15)
        pylab.savefig('dir_tun' + 'LO.png')
        
    elif region == 1:
        plt.title ("Medulla", fontsize = 20.)
        open('dir_tun' + 'ME.npy','w')
        np.save('dir_tun' + 'ME.npy', mean_tuning)
        ax.text(0.8, 0.8, "N={0}".format(np.shape(single_tuningsME)[0]), transform=ax.transAxes, fontsize=15)
        pylab.savefig('dir_tun' + 'ME.png')
        
    elif region == 2:
        plt.title ("Lobula Plate", fontsize = 20.)
        open('dir_tun' + 'LP.npy','w')
        np.save('dir_tun' + 'LP.npy', mean_tuning)
        ax.text(0.8, 0.8, "N={0}".format(np.shape(single_tuningsLP)[0]), transform=ax.transAxes, fontsize=15)
        pylab.savefig('dir_tun' + 'LP.png')

# %%
# Out:
# (2, 12, 5)
