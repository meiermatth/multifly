# %%
# %matplotlib inline
import sys
sys.path.append("/Users/mmeier/Desktop/new_arena/")
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
from scipy import stats
import data_analysis.tools as tools
import data_analysis.calcium_analysis as calcium_analysis
import pylab
from scipy import stats

# %% [markdown]
# # Use average ROIs

# %%
fly0_LO = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-07_19.20LO.npy').mean(1)
fly0_ME = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-07_19.20ME.npy').mean(1)
fly0_LP = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-07_19.20LP.npy').mean(1)

fly1_LO = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-15_18.13LO.npy').mean(1)
fly1_ME = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-15_18.13ME.npy').mean(1)
fly1_LP = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-15_18.13LP.npy').mean(1)

fly2_LO = np.load('T4T5_ctrl_temp_freq_2016-11-16_15.47LO.npy').mean(1)
fly2_ME = np.load('T4T5_ctrl_temp_freq_2016-11-16_15.47ME.npy').mean(1)
fly2_LP = np.load('T4T5_ctrl_temp_freq_2016-11-16_15.47LP.npy').mean(1)

fly3_LO = np.load('T4T5_ctrl_temp_freq_2016-11-18_18.46LO.npy').mean(1)
fly3_ME = np.load('T4T5_ctrl_temp_freq_2016-11-18_18.46ME.npy').mean(1)
fly3_LP = np.load('T4T5_ctrl_temp_freq_2016-11-18_18.46LP.npy').mean(1)

fly4_LO = np.load('T4T5_SHI_ctrl_temp_freq_2016-11-21_16.07LO.npy').mean(1)
fly4_ME = np.load('T4T5_SHI_ctrl_temp_freq_2016-11-21_16.07ME.npy').mean(1)
fly4_LP = np.load('T4T5_SHI_ctrl_temp_freq_2016-11-21_16.07LP.npy').mean(1)

fly5_LO = np.load('T4T5_ctrl_temp_freq_2016-11-29_16.05LO.npy').mean(1)
fly5_ME = np.load('T4T5_ctrl_temp_freq_2016-11-29_16.05ME.npy').mean(1)
fly5_LP = np.load('T4T5_ctrl_temp_freq_2016-11-29_16.05LP.npy').mean(1)

fly6_LO = np.load('T4T5_SHI_ctrl_temp_freq_2016-12-01_16.49LO.npy').mean(1)
fly6_ME = np.load('T4T5_SHI_ctrl_temp_freq_2016-12-01_16.49ME.npy').mean(1)
fly6_LP = np.load('T4T5_SHI_ctrl_temp_freq_2016-12-01_16.49LP.npy').mean(1)

single_tuningsLO = np.array([fly0_LO, fly1_LO, fly2_LO, fly3_LO, fly4_LO, fly5_LO, fly6_LO])
single_tuningsME = np.array([fly0_ME, fly1_ME, fly2_ME, fly3_ME, fly4_ME, fly5_ME, fly6_ME])
single_tuningsLP = np.array([fly0_LP, fly1_LP, fly2_LP, fly3_LP, fly4_LP, fly5_LP, fly6_LP])

SEM_LO = stats.sem(single_tuningsLO)
SEM_ME = stats.sem(single_tuningsME)
SEM_LP = stats.sem(single_tuningsLP)

mean_tuningLO = np.mean(single_tuningsLO, axis = 0)
mean_tuningME = np.mean(single_tuningsME, axis = 0)
mean_tuningLP = np.mean(single_tuningsLP, axis = 0)

mean_tuning = np.array([mean_tuningLO, mean_tuningME, mean_tuningLP])
SEMs = np.array([SEM_LO, SEM_ME, SEM_LP])

# %% [markdown]
# # Use only one large ROI

# %%
fly0_LO = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-07_19.20LO.npy')
fly0_LO = fly0_LO[:, 4]
fly0_ME = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-07_19.20ME.npy')
fly0_ME = fly0_ME[:, 4]
fly0_LP = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-07_19.20LP.npy')
fly0_LP = fly0_LP[:, 4]

fly1_LO = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-15_18.13LO.npy')
fly1_LO = fly1_LO[:, 4]
fly1_ME = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-15_18.13ME.npy')
fly1_ME = fly1_ME[:, 4]
fly1_LP = np.load('T4T5_ctrl_temp_freq_PDND_2016-11-15_18.13LP.npy')
fly1_LP = fly1_LP[:, 4]

fly2_LO = np.load('T4T5_ctrl_temp_freq_2016-11-16_15.47LO.npy')
fly2_LO = fly2_LO[:, 4]
fly2_ME = np.load('T4T5_ctrl_temp_freq_2016-11-16_15.47ME.npy')
fly2_ME = fly2_ME[:, 4]
fly2_LP = np.load('T4T5_ctrl_temp_freq_2016-11-16_15.47LP.npy')
fly2_LP = fly2_LP[:, 4]

fly3_LO = np.load('T4T5_ctrl_temp_freq_2016-11-18_18.46LO.npy')
fly3_LO = fly3_LO[:, 4]
fly3_ME = np.load('T4T5_ctrl_temp_freq_2016-11-18_18.46ME.npy')
fly3_ME = fly3_ME[:, 4]
fly3_LP = np.load('T4T5_ctrl_temp_freq_2016-11-18_18.46LP.npy')
fly3_LP = fly3_LP[:, 4]

fly4_LO = np.load('T4T5_SHI_ctrl_temp_freq_2016-11-21_16.07LO.npy')
fly4_LO = fly4_LO[:, 4]
fly4_ME = np.load('T4T5_SHI_ctrl_temp_freq_2016-11-21_16.07ME.npy')
fly4_ME = fly4_ME[:, 4]
fly4_LP = np.load('T4T5_SHI_ctrl_temp_freq_2016-11-21_16.07LP.npy')
fly4_LP = fly4_LP[:, 4]

fly5_LO = np.load('T4T5_ctrl_temp_freq_2016-11-29_16.05LO.npy')
fly5_LO = fly5_LO[:, 4]
fly5_ME = np.load('T4T5_ctrl_temp_freq_2016-11-29_16.05ME.npy')
fly5_ME = fly5_ME[:, 4]
fly5_LP = np.load('T4T5_ctrl_temp_freq_2016-11-29_16.05LP.npy')
fly5_LP = fly5_LP[ :, 4]

fly6_LO = np.load('T4T5_SHI_ctrl_temp_freq_2016-12-01_16.49LO.npy')
fly6_LO = fly6_LO[:, 4]
fly6_ME = np.load('T4T5_SHI_ctrl_temp_freq_2016-12-01_16.49ME.npy')
fly6_ME = fly6_ME[:, 4]
fly6_LP = np.load('T4T5_SHI_ctrl_temp_freq_2016-12-01_16.49LP.npy')
fly6_LP = fly6_LP[ :, 4]

single_tuningsLO = np.array([fly0_LO, fly1_LO, fly2_LO, fly3_LO, fly4_LO, fly5_LO, fly6_LO])
single_tuningsME = np.array([fly0_ME, fly1_ME, fly2_ME, fly3_ME, fly4_ME, fly5_ME, fly])
single_tuningsLP = np.array([fly0_LP, fly1_LP, fly2_LP, fly3_LP, fly4_LP, fly5_LP])

SEM_LO = stats.sem(single_tuningsLO)
SEM_ME = stats.sem(single_tuningsME)
SEM_LP = stats.sem(single_tuningsLP)

mean_tuningLO = np.mean(single_tuningsLO, axis = 0)
mean_tuningME = np.mean(single_tuningsME, axis = 0)
mean_tuningLP = np.mean(single_tuningsLP, axis = 0)

mean_tuning = np.array([mean_tuningLO, mean_tuningME, mean_tuningLP])
SEMs = np.array([SEM_LO, SEM_ME, SEM_LP])

# %%
# plot everything

regions = [0,1,2]

for region in regions:
    plt.figure(figsize = (5,5))
    ax = plt.subplot(111)

    # here, we manually define the x-axis
    frequency_tuning = [0.0625, 0.125, 0.25, 0.5, 1., 2., 4., 8.]

    # plot mean tuning as solid line
    plt.errorbar(frequency_tuning, mean_tuning[region,:], yerr=SEMs[region,:], color = 'b', linewidth = 3.0, marker = 'o')

    # plot single tunings with a lower alpha
    # plt.plot(frequency_tuning, mean_tuning, color = 'b', linewidth = 3.0, alpha = 0.3)
    plt.xscale('log')

    # define the x-axis and ticks etc...
    ax.set_xlim([0.05,30])
    ax.set_xticks([0.1,1.,10.])
    ax.set_xticklabels([0.1, 1, 10], fontsize = 15.)
    ax.set_xlabel('Frequency tuning [Hz]', fontsize = 20.)

    # define the y-axis and ticks etc...
    plt.ylim([0,1.1])
    ax.set_yticks([0.0, 0.5, 1.0])
    ax.set_yticklabels([0, 0.5, 1.0], fontsize = 20.)
    ax.set_ylabel('$\Delta F/F$', fontsize = 20.)
    
    if region == 0:
        plt.title ("Lobula", fontsize = 20.)
        open('temp_freq' + 'LO.npy','w')
        np.save('temp_freq' + 'LO.npy', mean_tuning)
        ax.text(0.8, 0.8, "N={0}".format(np.shape(single_tuningsLO)[0]), transform=ax.transAxes, fontsize=15)
        pylab.savefig('temp_freq' + 'LO.png')
        
    elif region == 1:
        plt.title ("Medulla", fontsize = 20.)
        open('temp_freq' + 'ME.npy','w')
        np.save('temp_freq' + 'ME.npy', mean_tuning)
        ax.text(0.8, 0.8, "N={0}".format(np.shape(single_tuningsLO)[0]), transform=ax.transAxes, fontsize=15)
        pylab.savefig('temp_freq' + 'ME.png')
        
    elif region == 2:
        plt.title ("Lobula Plate", fontsize = 20.)
        open('temp_freq' + 'LP.npy','w')
        np.save('temp_freq' + 'LP.npy', mean_tuning)
        ax.text(0.8, 0.8, "N={0}".format(np.shape(single_tuningsLO)[0]), transform=ax.transAxes, fontsize=15)
        pylab.savefig('temp_freq' + 'LP.png')
